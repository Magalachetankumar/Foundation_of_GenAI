# %%
# !pip install -U fastai fastprogress

# %%
from fastai.vision.all import *

# %%
learn.predict(get_image_files(path/"images")[0])
# Out:
# <div><table class="fastprogress"><thead><tr><th>epoch</th><th>train_loss</th><th>valid_loss</th><th>accuracy</th><th>time</th></tr></thead><tbody></tbody></table></div>
# ('Egyptian_Mau',
#  tensor(5),
#  tensor([2.8655e-05, 7.2826e-06, 2.6534e-10, 4.5021e-08, 2.2200e-08, 8.1139e-01,
#          1.9066e-04, 1.7524e-01, 4.4101e-07, 3.6750e-08, 1.8705e-08, 3.9809e-07,
#          3.6053e-05, 2.2506e-06, 9.6480e-08, 3.5725e-07, 4.1763e-07, 8.2674e-08,
#          1.8419e-07, 2.4491e-07, 8.3579e-06, 1.3322e-07, 3.4845e-08, 4.8567e-06,
#          1.0703e-02, 7.3672e-05, 4.9462e-08, 1.6025e-06, 5.4421e-04, 2.0135e-08,
#          5.2780e-09, 5.6970e-07, 1.0789e-05, 1.7563e-03, 3.8063e-08, 2.2752e-06,
#          3.3558e-08]))
