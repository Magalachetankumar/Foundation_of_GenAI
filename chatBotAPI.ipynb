# %%
pip install groq
# Out:
# Collecting groq
#   Downloading groq-1.0.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)
# Downloading groq-1.0.0-py3-none-any.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.3/138.3 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: groq
# Successfully installed groq-1.0.0

# %%
from groq import Groq

# Store your Groq API Key
GROQ_API_KEY = "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"

# Initialize Groq client
client = Groq(api_key=GROQ_API_KEY)

# Common function to interact with Groq AI
def ask_ai(prompt):
    response = client.chat.completions.create(
        model="llama-3.1-8b-instant",
        messages=[
            {"role": "user", "content": prompt}
        ]
    )
    return response.choices[0].message.content

# %%
print("\n--- ROOT PROMPT ---\n")

root_prompt = """
You are an expert Generative AI tutor.
Explain concepts clearly, step by step, using simple language.
"""

print(ask_ai(root_prompt + "Explain Prompt Engineering."))
# Out:
# --- ROOT PROMPT ---
#
# I'm glad you asked about Prompt Engineering, a crucial part of working with Generative AI models. I'll break it down in simple steps.
#
# **What is Prompt Engineering?**
#
# Prompt Engineering is the process of carefully crafting inputs (called "prompts") for AI models to generate specific, accurate, and relevant outputs. It's like writing a question or a task that tells the AI exactly what it should do.
#
# **Why is Prompt Engineering Important?**
#
# Think of AI models like a machine that needs instructions to do something specific. If the instructions are unclear, the machine might not give you the desired outcome. Prompt Engineering ensures that the AI understands the task, produces relevant responses, and avoids unwanted outcomes.
#
# **Step-by-Step Process of Prompt Engineering**
#
# 1. **Define the Task**: Clearly identify what task you want the AI to perform (e.g., generate text, classify images, summarize content).
# 2. **Know Your AI Model**: Understand the capabilities, strengths, and limitations of the AI model you're working with.
# 3. **Write a Clear Prompt**: Use natural language and specify the task, input data, and desired output in a concise and precise way. Keep in mind the AI model's limitations and biases.
# 4. **Test and Refine**: Test your prompt with a small dataset and refine it as needed to achieve the desired results.
# 5. **Consider Context and Nuances**: Think about the context in which the prompt will be used and account for nuances such as slang, idioms, and cultural references.
# 6. **Monitor and Adjust**: Continuously monitor the AI model's performance and adjust the prompt as needed to ensure optimal results.
#
# **Best Practices for Prompt Engineering**
#
# - Be specific and clear about the task
# - Provide relevant context
# - Use simple language (avoid jargon and technical terms)
# - Keep the prompt concise
# - Use active voice and imperatives (e.g., "Describe a sunny day" instead of "What is a sunny day like?")
# - Test and refine the prompt iteratively
#
# By following these steps and best practices, you can craft effective prompts that unlock the full potential of your AI model.

# %%
print("\n--- PERSONA PROMPT ---\n")

persona_prompt = """
Act as a college professor teaching Generative AI to undergraduate students.
Explain Prompt Engineering with real-life examples.
"""

print(ask_ai(persona_prompt))
# Out:
# --- PERSONA PROMPT ---
#
# Welcome, students, to today's lecture on Generative AI. As we've discussed previously, one of the key components of successful Generative AI models is the prompt engineering process. In this lecture, we'll delve into the world of prompt engineering and explore its significance in generating high-quality outputs.
#
# **What is Prompt Engineering?**
#
# Prompt engineering is the process of crafting carefully designed input prompts to elicit specific, informative, and coherent responses from language models. It's an art and science that requires a deep understanding of language, context, and the specific tasks you want to accomplish with your Generative AI model.
#
# **Why is Prompt Engineering Important?**
#
# In Generative AI, the quality of output is directly proportional to the quality of input. Well-crafted prompts can lead to more accurate, informative, and engaging outputs, while poorly designed prompts can result in irrelevant, biased, or nonsensical responses. By mastering prompt engineering, you can improve the performance of your Generative AI models and unlock their full potential.
#
# **Real-Life Examples of Prompt Engineering:**
#
# Let's consider some examples to illustrate the power of prompt engineering:
#
# 1. **Image Generation:**
#
# Suppose you want a Generative AI model to generate an image of a futuristic cityscape. A poorly designed prompt might be: "Create an image of a city."
#
# A better prompt would be: "Design a futuristic cityscape with towering skyscrapers, a busy street scene, and a vibrant atmosphere, inspired by the works of sci-fi artist Syd Mead."
#
# This revised prompt provides more context, specificity, and creativity parameters, resulting in a more accurate and visually appealing image.
#
# 2. **Text Generation:**
#
# Suppose you want a Generative AI model to generate a short story about a character who discovers a hidden treasure. A poorly designed prompt might be: "Write a story about a treasure hunt."
#
# A better prompt would be: "Create a short story about a young adventurer named Alexandra, who stumbles upon a mysterious map while exploring the attic of her family's old mansion. As she deciphers the cryptic symbols, she discovers a hidden treasure that changes her life forever, inspired by the style of classic adventure novels."
#
# This revised prompt provides more character development, plot structure, and literary references, resulting in a more engaging and coherent story.
#
# 3. **Dialogue Generation:**
#
# Suppose you want a Generative AI model to generate a conversation between two characters discussing the ethics of AI. A poorly designed prompt might be: "Create a conversation between two people about AI."
#
# A better prompt would be: "Write a conversation between a human ethicist and an AI researcher, discussing the pros and cons of implementing AI in healthcare, with a focus on patient autonomy and data privacy, influenced by the philosophical debates of philosophers like Daniel Dennett and Nick Bostrom."
#
# This revised prompt provides more context, specific topics, and intellectual references, resulting in a more nuanced and informed discussion.
#
# **Best Practices in Prompt Engineering:**
#
# To become proficient in prompt engineering, keep the following best practices in mind:
#
# 1. **Clarify your goals:** Before crafting a prompt, define what you want to achieve with your Generative AI model.
# 2. **Be specific:** Use concrete, descriptive language to provide context and parameters for your model.
# 3. **Show, don't tell:** Use examples, comparisons, and references to paint a vivid picture of what you want your model to generate.
# 4. **Consider the audience:** Tailor your prompt to the intended audience and their level of understanding.
# 5. **Iterate and refine:** As your model generates output, refine your prompt to improve the quality of results.
#
# **Conclusion:**
#
# Prompt engineering is a crucial aspect of Generative AI, and by mastering this skill, you can unlock the full potential of your models. Remember, a well-crafted prompt is like a recipe for generating high-quality outputs – with the right ingredients, you can create something truly remarkable.
#
# For your assignment, please submit a prompt that you believe would elicit a high-quality response from a Generative AI model. Don't forget to follow our best practices, and I look forward to seeing your creative prompts!

# %%
print("\n=== EXERCISE 4 ===\n")

# 1. Chain of Thought
cot_prompt = """
Explain step by step how AI detects spam emails.
Show your reasoning clearly.
"""

print("Chain of Thought Output:\n")
print(ask_ai(cot_prompt))
print("-" * 80)

# 2. Tabular Format
tabular_prompt = """
Explain the difference between AI, ML, and Deep Learning in a table.
"""

print("Tabular Format Output:\n")
print(ask_ai(tabular_prompt))
print("-" * 80)

# 3. Fill in the Blank
fill_blank_prompt = """
Fill in the blank:
Artificial Intelligence is the ability of machines to ______ human intelligence.
"""

print("Fill in the Blank Output:\n")
print(ask_ai(fill_blank_prompt))
print("-" * 80)

# 4. RGC Prompting
rgc_prompt = """
Role: You are an AI mentor.
Goal: Explain prompt engineering.
Context: The learner is a beginner with no AI background.
"""

print("RGC Prompt Output:\n")
print(ask_ai(rgc_prompt))
print("-" * 80)

# 5. Zero-Shot Prompting
zero_shot_prompt = """
Explain Natural Language Processing.
"""

print("Zero-Shot Output:\n")
print(ask_ai(zero_shot_prompt))
print("-" * 80)

# 6. One-Shot Prompting
one_shot_prompt = """
Example:
Input: What is AI?
Output: AI is the simulation of human intelligence by machines.

Now explain:
What is Machine Learning?
"""

print("One-Shot Output:\n")
print(ask_ai(one_shot_prompt))
print("-" * 80)

# 7. Few-Shot Prompting
few_shot_prompt = """
Input: AI
Output: Machines that simulate human intelligence.

Input: ML
Output: Systems that learn from data.

Input: Deep Learning
Output:
"""

print("Few-Shot Output:\n")
print(ask_ai(few_shot_prompt))
print("-" * 80)
# Out:
# === EXERCISE 4 ===
#
# Chain of Thought Output:
#
# Detecting spam emails involves a combination ofNatural Language Processing (NLP) and Machine Learning (ML) techniques. Here's a step-by-step explanation of how AI detects spam emails:
#
# **Step 1: Data Collection and Preprocessing**
#
# * Collect a large dataset of both legitimate and spam emails.
# * Preprocess the data by converting all text to lowercase, removing special characters, and extracting relevant features such as:
# 	+ Tokenization (breaking down text into individual words)
# 	+ Stopword removal (ignoring common words like "the", "and", etc.)
# 	+ Stemming or Lemmatization (reducing words to their base form)
# 	+ Named Entity Recognition (extracting names, locations, etc.)
#
# **Step 2: Feature Extraction**
#
# * Extract relevant features from the preprocessed data, including:
# 	+ Unigram statistics (frequency of individual words)
# 	+ Bigram statistics (frequency of pairs of words)
# 	+ Trigram statistics (frequency of triplets of words)
# 	+ Word embeddings (representing words as vectors in a high-dimensional space)
# 	+ Sentiment analysis (determining the emotional tone of the email)
# 	+ Grammar and syntax analysis (examining sentence structure and grammar)
#
# **Step 3: Machine Learning Model Training**
#
# * Train a machine learning model on the preprocessed and feature-extracted data using supervised learning techniques, such as:
# 	+ Logistic Regression
# 	+ Decision Trees
# 	+ Support Vector Machines (SVMs)
# 	+ Random Forests
# 	+ Neural Networks
# * The model learns to identify patterns in the data that are indicative of spam emails.
#
# **Step 4: Classification**
#
# * Use the trained model to classify new, incoming emails as either spam or legitimate based on their feature vectors.
# * The model predicts the likelihood that an email is spam, typically represented as a probability between 0 and 1.
#
# **Step 5: Thresholding**
#
# * Apply a threshold value to the model's predictions, typically above 0.5 or so, to determine whether an email is classified as spam or legitimate.
# * Emails with a prediction above the threshold are classified as spam.
#
# **Step 6: Post-processing**
#
# * Apply additional post-processing steps to refine the classification, such as:
# 	+ Confidence adjustment: adjusting the threshold based on the model's confidence in its predictions
# 	+ Prior probability adjustment: incorporating prior knowledge about the probability of spam emails in the system
# 	+ Human review: manually reviewing emails that are misclassified or have low confidence scores
#
# **Reasoning behind AI's detection**
#
# AI detects spam emails by identifying patterns and anomalies in the data that are indicative of spam emails. The techniques used, such as NLP, ML, and feature extraction, allow the AI to:
#
# * Identify words and phrases commonly used in spam emails
# * Detect anomalies in grammar and syntax
# * Recognize sentiment and emotional tone
# * Identify named entities and locations
# * Predict the likelihood of an email being spam based on its feature vector
#
# By applying these techniques, AI can accurately classify emails as spam or legitimate, helping to prevent spam from reaching users' inboxes.
# --------------------------------------------------------------------------------
# Tabular Format Output:
#
# Here's a table explaining the difference between AI, ML, and Deep Learning:
#
# | **Category** | **Description** | **Key Focus** |
# | --- | --- | --- |
# | **Artificial Intelligence (AI)** | A broad field that strives to create intelligent machines that can perform tasks that typically require human intelligence. | Developing intelligent systems that can perform various tasks, including reasoning, problem-solving, understanding natural language, and recognizing patterns. |
# | **Machine Learning (ML)** | A subset of AI that involves training algorithms to learn from data without being explicitly programmed. | Developing algorithms and models that can learn from data, identify patterns, and make predictions or decisions. |
# | **Deep Learning (DL)** | A type of Machine Learning that uses neural networks with multiple layers to learn complex patterns in data. | Developing neural networks with multiple hidden layers to learn abstract representations of data, allowing for tasks such as image recognition, natural language processing, and speech recognition. |
#
# In other words:
#
# - **AI** is the umbrella term that encompasses all forms of intelligent machines.
# - **ML** is a key technology within AI that allows machines to learn from data.
# - **DL** is a specific type of ML that uses neural networks to learn complex patterns in data.
#
# Here's a hierarchical representation of the relationship between AI, ML, and DL:
#
# 1. **AI** (umbrella term)
# 	* **ML** (subset of AI, focused on learning from data)
# 		+ **DL** (subset of ML, focused on using neural networks with multiple layers)
#
# I hope this helps clarify the relationships between these technologies!
# --------------------------------------------------------------------------------
# Fill in the Blank Output:
#
# Artificial Intelligence is the ability of machines to emulate human intelligence.
#
# However, it's worth mentioning that the more specific definition is that of Alan Turing; which is that Artificial intelligence is "the ability of machines to execute tasks that, if carried out by humans, would prove to require intelligence."
# --------------------------------------------------------------------------------
# RGC Prompt Output:
#
# Welcome to our session on Prompt Engineering! I'm excited to introduce you to this fascinating field.
#
# **What is Prompt Engineering?**
#
# Prompt engineering is the process of crafting high-quality input, called a "prompt," to elicit accurate, informative, and meaningful responses from an AI model or a language generation system. Think of it like cooking a recipe: you need to provide the right ingredients (prompt) in the right order to produce a delicious dish (response).
#
# **Why is Prompt Engineering Important?**
#
# In the context of AI and language generation, prompt engineering is crucial because:
#
# 1. **Accuracy and relevance**: A well-crafted prompt ensures that the AI model provides accurate and relevant information, reducing errors and ambiguity.
# 2. **Contextual understanding**: A good prompt helps the AI model understand the context and nuances of the question or topic, leading to more informed and useful responses.
# 3. **Efficiency**: With a well-designed prompt, AI models can process information more efficiently, reducing processing time and computational resources.
#
# **Key Concepts**
#
# To get started with prompt engineering, it's essential to understand:
#
# 1. **Prompt structure**: A prompt typically consists of a combination of natural language and specific instructions to guide the AI model.
# 2. **Task specification**: Clearly defining the task or intent behind the prompt helps the AI model understand what is expected.
# 3. **Context setup**: Providing background information or setup can help the AI model better understand the context and question.
#
# **Common Prompt Engineering Techniques**
#
# Some popular techniques used in prompt engineering include:
#
# 1. **Specificity**: Using specific keywords, phrases, or instructions to guide the AI model.
# 2. **Contextualization**: Providing relevant background information or setup to help the AI model understand the context.
# 3. **Concreteness**: Using concrete language and examples to make the prompt more actionable.
# 4. **Clarity**: Ensuring that the prompt is clear, concise, and unambiguous.
#
# **Best Practices**
#
# To become proficient in prompt engineering, here are some best practices to keep in mind:
#
# 1. **Start with a clear purpose**: Define the intent and task behind the prompt.
# 2. **Use plain language**: Avoid jargon, technical terms, or complex concepts that might confuse the AI model.
# 3. **Be concise**: Keep the prompt brief and to the point.
# 4. **Use examples**: Use concrete examples or scenarios to illustrate the prompt.
# 5. **Test and refine**: Test the prompt and refine it based on the AI model's responses.
#
# In our next session, we'll dive deeper into some practical exercises and examples of prompt engineering in action.
#
# How was this introduction to prompt engineering? Do you have any questions or areas you'd like to explore further?
# --------------------------------------------------------------------------------
# Zero-Shot Output:
#
# **What is Natural Language Processing (NLP)?**
#
# Natural Language Processing (NLP) is a subfield of artificial intelligence (AI) and linguistics that deals with the interaction between computers and human language. It's a multidisciplinary field that combines computer science, mathematics, and linguistics to enable computers to process, understand, and generate human language.
#
# **Goals of NLP:**
#
# The primary goals of NLP are:
#
# 1. **Text Analysis**: Break down human language into smaller units, such as tokens, syntax, and semantics, to extract meaningful information.
# 2. **Text Generation**: Synthesize human-like language to generate text, such as chatbots, language translation, and text summarization.
# 3. **Language Understanding**: Enable computers to comprehend the meaning and context of human language, including sentiment analysis, entity recognition, and intent detection.
#
# **Key NLP Techniques:**
#
# 1. **Tokenization**: Breaking down text into individual words or tokens.
# 2. **Part-of-Speech (POS) Tagging**: Identifying the grammatical categories (e.g., noun, verb, adjective) of each token.
# 3. **Named Entity Recognition (NER)**: Identifying named entities (e.g., people, places, organizations) in text.
# 4. **Dependency Parsing**: Analyzing the grammatical structure of sentences.
# 5. **Machine Learning**: Training AI models on large datasets to learn patterns in language.
# 6. **Deep Learning**: Using neural networks to analyze complex language phenomena, such as context and nuance.
#
# **NLP Applications:**
#
# 1. **Chatbots**: Conversational interfaces that use NLP to understand user input and respond with relevant text.
# 2. **Language Translation**: Automatic translation of text from one language to another.
# 3. **Sentiment Analysis**: Analyzing text to determine the author's attitude or emotion.
# 4. **Text Summarization**: Automatically generating a concise summary of a long piece of text.
# 5. **Speech Recognition**: Converting spoken language into written text.
# 6. **Text Classification**: Categorizing text into predefined categories (e.g., spam vs. non-spam emails).
#
# **Challenges in NLP:**
#
# 1. **Ambiguity**: Language is often ambiguous, and context is crucial for understanding meaning.
# 2. **Sarcasm and Irony**: Detecting humor, sarcasm, and irony can be challenging for AI models.
# 3. **Idioms and Colloquialisms**: Idioms, colloquialisms, and dialects can confuse AI models.
# 4. **Noise and Error**: Text data can contain errors, typos, and formatting issues.
#
# **Future of NLP:**
#
# As AI technology advances, NLP is becoming increasingly important for various industries, including:
#
# 1. **Customer Service**: Chatbots and voice assistants are becoming more prevalent.
# 2. **Language Translation**: Improved translation quality and decreased costs.
# 3. **Content Creation**: AI-generated content, such as articles and dialogues, is becoming more common.
# 4. **Healthcare**: NLP is used in medical research, patient communication, and diagnosis.
#
# By understanding the complexities of human language and developing sophisticated AI models, NLP is transforming the world of technology and beyond.
# --------------------------------------------------------------------------------
# One-Shot Output:
#
# Machine Learning (ML) is a subset of Artificial Intelligence (AI) that involves the development of algorithms and statistical models that enable machines to learn and improve from data without being explicitly programmed.
#
# In simpler terms, Machine Learning is a type of AI that allows computers to learn from experience and make predictions or decisions based on the data they have been trained on.
#
# Here is a more detailed explanation:
#
# Machine Learning involves training a model on a dataset, and the model learns to make decisions or predictions based on patterns and correlations in the data. The model can then be used to make predictions or classify new, unseen data. Over time, the model can continue to learn and improve its performance as it is exposed to more data.
#
# Key characteristics of Machine Learning include:
#
# 1. **Autonomous learning**: The model can learn and improve on its own, without the need for explicit programming.
# 2. **Data-driven**: The model is trained on a dataset and learns from it.
# 3. **Pattern recognition**: The model identifies patterns and correlations in the data to make predictions or decisions.
# 4. **Improves over time**: The model can continue to learn and improve its performance as it is exposed to more data.
#
# Some common applications of Machine Learning include:
#
# 1. Image recognition
# 2. Natural Language Processing (NLP)
# 3. Predictive maintenance
# 4. Recommendation systems
# 5. Sentiment analysis
#
# In summary, Machine Learning is a powerful tool that enables machines to learn and improve from data, making it a key part of many modern AI applications.
# --------------------------------------------------------------------------------
# Few-Shot Output:
#
# Input: Deep Learning
# Output: A type of Machine Learning (ML) that involves the use of neural networks with multiple layers to analyze complex data patterns. It is particularly effective for image and speech recognition, natural language processing, and other applications requiring nuanced pattern recognition.
# --------------------------------------------------------------------------------
